# %% [markdown]
# ## 🦁 Praktikum 1

# %% [markdown]
# Langkah 1 - Import Library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# Langkah 2 – Pra Pengolahan Data

# %% [markdown]
# 2.1 Data Training

# %%
train_datagen = ImageDataGenerator(
    rescale = 1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True)

training_set = train_datagen.flow_from_directory(
    'dataset/training_set',
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# 2.2 Data Testing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)

test_set = test_datagen.flow_from_directory(
    'dataset/test_set',
    target_size = (64, 64),
    batch_size = 32,
    class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# Langkah 3 — Pembuatan Model CNN

# %% [markdown]
# 3.1 Inisiasi Model

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# 3.2 Layer Konvolusi 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# 3.3 Max Pooling 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# 3.4 Konvolusi 2 + Max Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# 3.5 Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# 3.6 Fully Connected Layer 1

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# 3.7 Fully Connected Layer 2 (Output Layer)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# 3.8 Compile Model

# %%
cnn.compile(
    optimizer = 'adam',
    loss = 'binary_crossentropy',
    metrics = ['accuracy'])

# %% [markdown]
# Langkah 4 — Train Model

# %%
cnn.fit(
    x = training_set,
    validation_data = test_set,
    epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 211s 839ms/step - accuracy: 0.5644 - loss: 0.6780 - val_accuracy: 0.6130 - val_loss: 0.6521
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 23s 91ms/step - accuracy: 0.6528 - loss: 0.6246 - val_accuracy: 0.6090 - val_loss: 0.6375
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - accuracy: 0.6898 - loss: 0.5822 - val_accuracy: 0.7330 - val_loss: 0.5403
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - accuracy: 0.7322 - loss: 0.5383 - val_accuracy: 0.7570 - val_loss: 0.5106
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 25s 102ms/step - accuracy: 0.7423 - loss: 0.5234 - val_accuracy: 0.7625 - val_loss: 0.4978
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - accuracy: 0.7601 - loss: 0.4942 - val_accuracy: 0.7635 - val_loss: 0.5009
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 29s 116ms/step - accuracy: 0.7701 - loss: 0.4799 - val_accuracy: 0.7305 - val_loss: 0.5511
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 107ms/step - accuracy: 0.7757 - loss: 0.4640 - val_accuracy: 0.7245 - val_loss: 0.5531
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 124ms/step - accuracy: 0.7880 - loss: 0.4436 - val_accuracy: 0.7740 - val_loss: 0.4942
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 106ms/step - accuracy: 0.7966 - loss: 0.4335 - val_accuracy: 0.7725 - val_loss: 0.4865
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 107ms/step - accuracy: 0.8037 - loss: 0.4158 - val_accuracy: 0.7840 - val_loss: 0.4723
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 125ms/step - accuracy: 0.8124 - loss: 0.4082 - val_accuracy: 0.8000 - val_loss: 0.4583
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 123ms/step - accuracy: 0.8217 - loss: 0.3902 - val_accuracy: 0.7730 - val_loss: 0.4949
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 33s 132ms/step - accuracy: 0.8278 - loss: 0.3825 - val_accuracy: 0.7870 - val_loss: 0.4717
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 112ms/step - accuracy: 0.8340 - loss: 0.3727 - val_accuracy: 0.7990 - val_loss: 0.4705
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 113ms/step - accuracy: 0.8361 - loss: 0.3612 - val_accuracy: 0.7970 - val_loss: 0.4560
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 107ms/step - accuracy: 0.8466 - loss: 0.3461 - val_accuracy: 0.7770 - val_loss: 0.4892
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - accuracy: 0.8566 - loss: 0.3362 - val_accuracy: 0.7715 - val_loss: 0.5227
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - accuracy: 0.8570 - loss: 0.3241 - val_accuracy: 0.7925 - val_loss: 0.4874
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - accuracy: 0.8566 - loss: 0.3238 - val_accuracy: 0.8055 - val_loss: 0.4880
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - accuracy: 0.8735 - loss: 0.2981 - val_accuracy: 0.7835 - val_loss: 0.4714
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 110ms/step - accuracy: 0.8748 - loss: 0.2959 - val_accuracy: 0.8125 - val_loss: 0.4682
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 109ms/step - accuracy: 0.8848 - loss: 0.2786 - val_accuracy: 0.7975 - val_loss: 0.5179
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 107ms/step - accuracy: 0.8840 - loss: 0.2703 - val_accuracy: 0.7925 - val_loss: 0.5282
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 30s 120ms/step - accuracy: 0.8939 - loss: 0.2507 - val_accuracy: 0.7990 - val_loss: 0.5115

# %% [markdown]
# Langkah 5 — Prediksi Citra Tunggal

# %%
import numpy as np
from keras.preprocessing import image

# Load gambar
test_image = image.load_img(
    'dataset/single_prediction/cat_or_dog_1.jpg',
    target_size = (64, 64))

# Ubah ke array
test_image = image.img_to_array(test_image)

# Tambah dimensi agar sesuai input model
test_image = np.expand_dims(test_image, axis = 0)

# Prediksi
result = cnn.predict(test_image)
print(result)

# Menampilkan label kelas
print(training_set.class_indices)

# Interpretasi hasil
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'

print("Prediction Result:", prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [[1.]]
# {'cats': 0, 'dogs': 1}
# Prediction Result: dog
